# %%
import pandas as pd
import tensorflow as ttf
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# %%
train_data = pd.read_csv("../data/train.csv")
test_data = pd.read_csv("../data/test.csv")
unseen_data = train_data.sample(500)

df = train_data.drop(unseen_data.index)

# %%
columns_to_drop = [
    'ID',                
    'tce_match',         
    'tce_div_match',     
    'cyto_score_detail', 
    'mrd_hct',      
    'efs_time',
]

categorical_columns_ohe = [
    'tbi_status',
    'graft_type',
    'prim_disease_hct',
    'prod_type',
    'conditioning_intensity',
    'ethnicity',
    'race_group',
    'donor_related',
]

categorical_columns_le = [
    'hla_match_c_high',      
    'hla_high_res_8',
    'hla_high_res_6',
    'hla_high_res_10',
    'hla_match_dqb1_high',
    'hla_match_drb1_high',
    'hla_match_c_low',
    'hla_match_a_high',
    'hla_match_a_low',
    'hla_match_b_high',
    'hla_match_b_low',
    'hla_match_dqb1_low',
    'hla_match_drb1_low',
    'hla_low_res_6',
    'hla_low_res_8',
    'hla_low_res_10',
]

numerical_columns = [
    'age_at_hct',
    'donor_age',
    'comorbidity_score',
    'karnofsky_score',
]

target_column = [
    'efs'
]

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

def create_pipeline():
    columns_to_drop = [
        'ID',                
        'tce_match',         
        'tce_div_match',     
        'cyto_score_detail', 
        'mrd_hct',      
        'efs_time',
    ]

    categorical_columns_ohe = [
        'tbi_status',
        'graft_type',
        'prim_disease_hct',
        'prod_type',
        'conditioning_intensity',
        'ethnicity',
        'race_group',
        'donor_related',
    ]

    categorical_columns_le = [
        'hla_match_c_high',      
        'hla_high_res_8',
        'hla_high_res_6',
        'hla_high_res_10',
        'hla_match_dqb1_high',
        'hla_match_drb1_high',
        'hla_match_c_low',
        'hla_match_a_high',
        'hla_match_a_low',
        'hla_match_b_high',
        'hla_match_b_low',
        'hla_match_dqb1_low',
        'hla_match_drb1_low',
        'hla_low_res_6',
        'hla_low_res_8',
        'hla_low_res_10',
    ]

    numerical_columns = [
        'age_at_hct',
        'donor_age',
        'comorbidity_score',
        'karnofsky_score',
    ]

    target_column = 'efs'

    drop_transformer = ('drop_columns', 'drop', columns_to_drop)

    ohe_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore'))
    ])

    numerical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])

    le_transformers = {}
    for col in categorical_columns_le:
        le_transformers[col] = LabelEncoder()

    preprocessor = ColumnTransformer(
        transformers=[
            ('ohe', ohe_transformer, categorical_columns_ohe),
            ('num', numerical_transformer, numerical_columns),
            drop_transformer,
        ],
        remainder='passthrough'
    )

    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
    ])

    return pipeline, le_transformers

def preprocess_with_pipeline(pipeline, le_transformers, df, fit=True):
    for col, le in le_transformers.items():
        df[col] = df[col].fillna("Unknown").astype(str)
        if fit:
            df[col] = le.fit_transform(df[col])
        else:
            df[col] = le.transform(df[col])

    processed_data = pipeline.fit_transform(df) if fit else pipeline.transform(df)

    ohe_columns = pipeline.named_steps['preprocessor'].transformers_[0][1]['onehot'].get_feature_names_out()
    remaining_columns = list(df.columns.drop(categorical_columns_ohe + columns_to_drop))

    final_columns = list(ohe_columns) + remaining_columns
    processed_df = pd.DataFrame(processed_data, columns=final_columns)

    return processed_df

# %%
pipeline, le_transformers = create_pipeline()

train_preprocessed = preprocess_with_pipeline(pipeline, le_transformers, df, fit=True)
# Out:
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/ahmadabdullah/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
train_preprocessed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28300 entries, 0 to 28299
# Data columns (total 94 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   x0_No TBI                                     28300 non-null  object
#  1   x0_TBI + Cy +- Other                          28300 non-null  object
#  2   x0_TBI +- Other, -cGy, fractionated           28300 non-null  object
#  3   x0_TBI +- Other, -cGy, single                 28300 non-null  object
#  4   x0_TBI +- Other, -cGy, unknown dose           28300 non-null  object
#  5   x0_TBI +- Other, <=cGy                        28300 non-null  object
#  6   x0_TBI +- Other, >cGy                         28300 non-null  object
#  7   x0_TBI +- Other, unknown dose                 28300 non-null  object
#  8   x1_Bone marrow                                28300 non-null  object
#  9   x1_Peripheral blood                           28300 non-null  object
#  10  x2_AI                                         28300 non-null  object
#  11  x2_ALL                                        28300 non-null  object
#  12  x2_AML                                        28300 non-null  object
#  13  x2_CML                                        28300 non-null  object
#  14  x2_HD                                         28300 non-null  object
#  15  x2_HIS                                        28300 non-null  object
#  16  x2_IEA                                        28300 non-null  object
#  17  x2_IIS                                        28300 non-null  object
#  18  x2_IMD                                        28300 non-null  object
#  19  x2_IPA                                        28300 non-null  object
#  20  x2_MDS                                        28300 non-null  object
#  21  x2_MPN                                        28300 non-null  object
#  22  x2_NHL                                        28300 non-null  object
#  23  x2_Other acute leukemia                       28300 non-null  object
#  24  x2_Other leukemia                             28300 non-null  object
#  25  x2_PCD                                        28300 non-null  object
#  26  x2_SAA                                        28300 non-null  object
#  27  x2_Solid tumor                                28300 non-null  object
#  28  x3_BM                                         28300 non-null  object
#  29  x3_PB                                         28300 non-null  object
#  30  x4_MAC                                        28300 non-null  object
#  31  x4_N/A, F(pre-TED) not submitted              28300 non-null  object
#  32  x4_NMA                                        28300 non-null  object
#  33  x4_No drugs reported                          28300 non-null  object
#  34  x4_RIC                                        28300 non-null  object
#  35  x4_TBD                                        28300 non-null  object
#  36  x5_Hispanic or Latino                         28300 non-null  object
#  37  x5_Non-resident of the U.S.                   28300 non-null  object
#  38  x5_Not Hispanic or Latino                     28300 non-null  object
#  39  x6_American Indian or Alaska Native           28300 non-null  object
#  40  x6_Asian                                      28300 non-null  object
#  41  x6_Black or African-American                  28300 non-null  object
#  42  x6_More than one race                         28300 non-null  object
#  43  x6_Native Hawaiian or other Pacific Islander  28300 non-null  object
#  44  x6_White                                      28300 non-null  object
#  45  x7_Multiple donor (non-UCB)                   28300 non-null  object
#  46  x7_Related                                    28300 non-null  object
#  47  x7_Unrelated                                  28300 non-null  object
#  48  dri_score                                     28300 non-null  object
#  49  psych_disturb                                 28300 non-null  object
#  50  cyto_score                                    28300 non-null  object
#  51  diabetes                                      28300 non-null  object
#  52  hla_match_c_high                              28147 non-null  object
#  53  hla_high_res_8                                26272 non-null  object
#  54  arrhythmia                                    20378 non-null  object
#  55  hla_low_res_6                                 26220 non-null  object
#  56  vent_hist                                     28300 non-null  object
#  57  renal_issue                                   28300 non-null  object
#  58  pulm_severe                                   26138 non-null  object
#  59  hla_high_res_6                                28300 non-null  object
#  60  cmv_status                                    28049 non-null  object
#  61  hla_high_res_10                               26418 non-null  object
#  62  hla_match_dqb1_high                           26201 non-null  object
#  63  tce_imm_match                                 28300 non-null  object
#  64  hla_nmdp_6                                    27675 non-null  object
#  65  hla_match_c_low                               28300 non-null  object
#  66  rituximab                                     28300 non-null  object
#  67  hla_match_drb1_low                            17358 non-null  object
#  68  hla_match_dqb1_low                            24173 non-null  object
#  69  year_hct                                      28300 non-null  object
#  70  obesity                                       26182 non-null  object
#  71  in_vivo_tcd                                   28300 non-null  object
#  72  hla_match_a_high                              28300 non-null  object
#  73  hepatic_severe                                28300 non-null  object
#  74  donor_age                                     26567 non-null  object
#  75  prior_tumor                                   28077 non-null  object
#  76  hla_match_b_low                               28300 non-null  object
#  77  peptic_ulcer                                  26470 non-null  object
#  78  age_at_hct                                    26655 non-null  object
#  79  hla_match_a_low                               28300 non-null  object
#  80  gvhd_proph                                    25925 non-null  object
#  81  rheum_issue                                   28300 non-null  object
#  82  sex_match                                     28077 non-null  object
#  83  hla_match_b_high                              26157 non-null  object
#  84  comorbidity_score                             28043 non-null  object
#  85  karnofsky_score                               28300 non-null  object
#  86  hepatic_mild                                  26423 non-null  object
#  87  melphalan_dose                                26922 non-null  object
#  88  hla_low_res_8                                 28300 non-null  object
#  89  cardiac                                       25804 non-null  object
#  90  hla_match_drb1_high                           28300 non-null  object
#  91  pulm_moderate                                 26286 non-null  object
#  92  hla_low_res_10                                28300 non-null  object
#  93  efs                                           28300 non-null  object
# dtypes: object(94)
# memory usage: 20.3+ MB
